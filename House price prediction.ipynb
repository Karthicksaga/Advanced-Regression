# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import missingno as mg
import seaborn as sns
# %matplotlib inline

# %%
data_train = pd.read_csv("train.csv")
data_test = pd.read_csv("test.csv")

# %%
data_train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
data_test.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5  1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6  1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7  1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8  1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9  1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# ...

# %%
print("Train Data Info",data_train.info())
print("Test Data Info" ,data_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
print("Training null Value Data")
data_train.isnull().sum()
# Out:
# Training null Value Data
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
print("columns in the Dataset", data_train.columns)
# Out:
# columns in the Dataset Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
data_train.set_index("Id")
feature_null = [feature for feature in data_train.columns if data_train[feature].dtype != 'O']

# %%
print("Numerical Variable")
data_train[feature_null].head()
# Out:
# Numerical Variable
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
# ...

# %%
data_train[feature_null].isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
for feature in feature_null:
    sns.distplot(data_train[feature])
    plt.show()
    plt.title(feature)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-0201f737a380> in <module>
#       1 for feature in feature_null:
# ----> 2     sns.distplot(data_train[feature])
#       3     plt.show()
#       4     plt.title(feature)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
# ...

# %%
numerical_missing = [feature for feature in data_train.columns if (data_train[feature].isnull().sum() >= 1 and data_train[feature].dtype != 'O')]
data_train[numerical_missing].head()
# Out:
#    LotFrontage  MasVnrArea  GarageYrBlt
# 0         65.0       196.0       2003.0
# 1         80.0         0.0       1976.0
# 2         68.0       162.0       2001.0
# 3         60.0         0.0       1998.0
# 4         84.0       350.0       2000.0

# %%
sns.distplot(data_train["LotArea"])

# %%
data_train["LotArea"] = np.log(data_train["LotArea"])
data_train["LotArea"].head()
# Out:
# 0    2.201872
# 1    2.215885
# 2    2.233034
# 3    2.215315
# 4    2.258133
# Name: LotArea, dtype: float64

# %%
plt.scatter(data_train["LotArea"] , data_train["SalePrice"])
plt.title("Relationship between LotArea and SalePrice")
# Out:
# Text(0.5, 1.0, 'Relationship between LotArea and SalePrice')

# %%
sns.distplot(data_train["LotFrontage"])
plt.title("LotFrontage")
# Out:
# Text(0.5, 1.0, 'LotFrontage')

# %%
sns.heatmap(data_train[numerical_missing] ,annot =True)

# %%
sns.distplot(data_train["SalePrice"],norm_hist=True)

# %%
print("train_data skew",data_train["SalePrice"].skew())
# Out:
# train_data skew 1.8828757597682129

# %%
data_train[numerical_missing].isnull().sum()
# Out:
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# dtype: int64

# %%
numerical_null = [feature for feature in data_train.columns if data_train[feature].dtype!= "O" and data_train[feature].isnull().sum()>1]
data_train[numerical_null].mean().sort_values().plot.bar()

# %%
for feature in numerical_null:
    data_train.groupby(data_train[feature])["SalePrice"].mean().plot.bar()

# %%
for miss in numerical_missing:
    mean = data_train[miss].mean()
    data_train[miss] = data_train[miss].fillna(mean)

# %%
data_train.set_index("Id").head()
# Out:
#     MSSubClass MSZoning  LotFrontage   LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0  2.201872   Pave   NaN      Reg
# 2           20       RL         80.0  2.215885   Pave   NaN      Reg
# 3           60       RL         68.0  2.233034   Pave   NaN      IR1
# 4           70       RL         60.0  2.215315   Pave   NaN      IR1
# 5           60       RL         84.0  2.258133   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
# ...

# %%
#Relationship between numerical and independent variable
data1 = data_train.copy()
dataset = data1.groupby(feature_null)["salesprice"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-8aa15e338632> in <module>
#       1 #Relationship between numerical and independent variable
#       2 data1 = data_train.copy()
# ----> 3 dataset = data1.groupby(feature_null)["salesprice"].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1611                 stacklevel=2,
#    1612             )
# -> 1613         return super().__getitem__(key)
#    1614
#    1615     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     237         else:
#     238             if key not in self.obj:
# --> 239                 raise KeyError(f"Column not found: {key}")
#     240             return self._gotitem(key, ndim=1)
#     241
#
# KeyError: 'Column not found: salesprice'

# %%
categorical_value = [feature for feature in data_train.columns if data_train[feature].dtype == "O"]
print(len(categorical_value))
print(data_train[categorical_value].isnull().sum())
# Out:
# 43
# MSZoning            0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinType2       38
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         0
# Functional          0
# FireplaceQu       690
# GarageType         81
# GarageFinish       81
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# ...

# %%
for feature in categorical_value:
    dataset = data_train.copy()
    dataset[feature] = np.where(dataset[feature].isnull(),1,0)
    dataset.groupby(feature)["SalePrice"].median().plot.bar()
    plt.title(feature)
    plt.show()

# %%
data_train.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#plot for bivarient analysis
def bivarient(independent ,dependent):
    sns.swarmplot(x = independent ,y = dependent ,data = data_train)
    sns.scatterplot(x = independent , y = dependent ,data = data_train)
    sns.jointplot(x = independent ,y = dependent ,data = data_train)

# %%
bivarient("MSSubClass" , "SalePrice")

# %%
sns.scatterplot(x = "MSSubClass" , y = "SalePrice" ,data = data_train)

# %%
bivarient("LotFrontage" ,"SalePrice")

# %%
mg.matrix(data_train[categorical_value])

# %%
for feature in categorical_value:
    print("Total unique Value and its {}:{}".format(feature ,data_train[feature].nunique()))
# Out:
# Total unique Value and its MSZoning:5
# Total unique Value and its Street:2
# Total unique Value and its Alley:2
# Total unique Value and its LotShape:4
# Total unique Value and its LandContour:4
# Total unique Value and its Utilities:2
# Total unique Value and its LotConfig:5
# Total unique Value and its LandSlope:3
# Total unique Value and its Neighborhood:25
# Total unique Value and its Condition1:9
# Total unique Value and its Condition2:8
# Total unique Value and its BldgType:5
# Total unique Value and its HouseStyle:8
# Total unique Value and its RoofStyle:6
# Total unique Value and its RoofMatl:8
# Total unique Value and its Exterior1st:15
# Total unique Value and its Exterior2nd:16
# Total unique Value and its MasVnrType:4
# Total unique Value and its ExterQual:4
# Total unique Value and its ExterCond:5
# Total unique Value and its Foundation:6
# Total unique Value and its BsmtQual:4
# Total unique Value and its BsmtCond:4
# Total unique Value and its BsmtExposure:4
# ...

# %%
data_train["MSZoning"].value_counts().plot.pie(autopct = "%1.1f%%" ,shadow = True)

# %%
#for featue in categorical_value:
def piechart(categorical_values):
    for featue in categorical_value:
        dataset = data_train.copy()
        data_train[feature].value_counts().plot.pie(autopct = "%1.1f%%" ,shadow = True )
        plt.show()
    return feature

# %%
piechart(categorical_value)
# Out:
# 'SaleCondition'

# %%
categorical_value
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in categorical_value:
    data=dataset.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %% [markdown]
# # Handling categorical Missing Value

# %%
data_train.Alley = data_train.Alley.fillna("None")
data_train.Alley.isnull().sum()
# Out:
# 0

# %%
data = ["PoolQC" ,"Fence" , "MiscFeature"]
for feature in data:
    data_train[feature] = data_train[feature].fillna("None")
    print(data_train[feature].isnull().sum())
# Out:
# 0
# 0
# 0

# %%
data = ["GarageType" ,"GarageFinish" ,"GarageQual","GarageCond"]
for feature in data:
    print(data_train[feature].value_counts())
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64

# %%
data_train["GarageCond"] = data_train["GarageCond"].fillna("TA")
data_train["GarageQual"] = data_train["GarageQual"].fillna("TA")
data_train["GarageFinish"] = data_train["GarageFinish"].fillna("Unf")
data_train["GarageType"] = data_train["GarageType"].fillna("Attchd")

# %%
data_train[categorical_value].isnull().sum()
# Out:
# MSZoning         0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       8
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinType2     0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# KitchenQual      0
# Functional       0
# FireplaceQu      0
# GarageType       0
# GarageFinish     0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# PoolQC           0
# Fence            0
# MiscFeature      0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
data = ["BsmtQual",
"BsmtCond",          
"BsmtExposure",      
"BsmtFinType1" ,      
"BsmtFinType2",      
"Electrical",         
"FireplaceQu"]    

for feature in data:
    data_train[feature] = data_train[feature].fillna("None")

# %%
print("shape of the Data set{}".format(data_train.shape))
# Out:
# shape of the Data set(1460, 81)

# %%
data_train.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.009601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.357056 -0.139781     0.032628
# LotFrontage   -0.009601   -0.357056     1.000000  0.306795     0.234196
# LotArea       -0.033226   -0.139781     0.306795  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.234196  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.052820 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.117598  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.082746  0.013788     0.550684
# MasVnrArea    -0.050199    0.022895     0.179283  0.103960     0.410238
# BsmtFinSF1    -0.005024   -0.069836     0.215828  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.043340  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.122156 -0.002618     0.308159
# ...

# %%
from sklearn.preprocessing import LabelEncoder
dataset = data_train.copy()
for feature in categorical_value:
    le = LabelEncoder().fit_transform(data_train[feature].values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     111         try:
# --> 112             res = _encode_python(values, uniques, encode)
#     113         except TypeError:
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode_python(values, uniques, encode)
#      59     if uniques is None:
# ---> 60         uniques = sorted(set(values))
#      61         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-c9c7deffa40f> in <module>
#       2 dataset = data_train.copy()
# ...

# %%
data_train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL    65.000000     8450   Pave  None      Reg
# 1   2          20       RL    80.000000     9600   Pave  None      Reg
# 2   3          60       RL    68.000000    11250   Pave  None      IR1
# 3   4          70       RL    60.000000     9550   Pave  None      IR1
# 4   5          60       RL    84.000000    14260   Pave  None      IR1
# 5   6          50       RL    85.000000    14115   Pave  None      IR1
# 6   7          20       RL    75.000000    10084   Pave  None      Reg
# 7   8          60       RL    70.049958    10382   Pave  None      IR1
# 8   9          50       RM    51.000000     6120   Pave  None      Reg
# 9  10         190       RL    50.000000     7420   Pave  None      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0   None   None        None       0
# ...

# %%
categorical_value
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
dataset = data_train.copy()
dataset = pd.get_dummies(dataset ,drop_first = True)

# %%
tradataset.shape
# Out:
# (1460, 258)

# %%
from sklearn.preprocessing import StandardScaler ,MinMaxScaler
from sklearn.metrics import r2_score ,mean_squared_error,mean_absolute_error,median_absolute_error
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression ,Lasso ,Ridge

# %%
x = dataset.drop(["Id" ,"SalePrice"] ,axis = 1)
y = dataset["SalePrice"]

# %%
x.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLI  \
# 0          2003       196.0         706           0  ...               0
# 1          1976         0.0         978           0  ...               0
# 2          2002       162.0         486           0  ...               0
# 3          1970         0.0         216           0  ...               0
# 4          2000       350.0         655           0  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25 ,random_state = 0)
print(x_train.shape ,y_train.shape)
# Out:
# (1095, 256) (1095,)

# %%
lg = LinearRegression()
reg = lg.fit(x_train,y_train)

# %%
reg.intercept_
# Out:
# -904923.4850249505

# %%
reg.coeffi_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-4d894c9bff86> in <module>
# ----> 1 reg.coeffi_
#
# AttributeError: 'LinearRegression' object has no attribute 'coeffi_'

# %%
print(r2_score(y_test , reg.predict(x_test)))
# Out:
# 0.5710041309405876

# %%
alpha = [0.1,0.01,10,1,100]
for i,alpha in enumerate(alpha):
    lg = Lasso(alpha = alpha).fit(x_train ,y_train)
    print("mean_squrared Error :{}".format(mean_squared_error(y_test ,lg.predict(x_test))))
    print("training Acuuracy:{}".format(r2_score(x_train ,y_train)))
    print("testing Accuracy_score:{}".format(r2_score(y_test ,lg.predict(x_test))))
# Out:
# mean_squrared Error :2762466642.934044
# C:\Users\Karthick\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187340624680.08212, tolerance: 679805682.3059437
#   positive)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-1cc1a69cf368> in <module>
#       3     lg = Lasso(alpha = alpha).fit(x_train ,y_train)
#       4     print("mean_squrared Error :{}".format(mean_squared_error(y_test ,lg.predict(x_test))))
# ----> 5     print("training Acuuracy:{}".format(r2_score(x_train ,y_train)))
#       6     print("testing Accuracy_score:{}".format(r2_score(y_test ,lg.predict(x_test))))
#       7
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
# ...

# %%
lg = Lasso(alpha = 1.0).fit(x_train ,y_train)
print("mean_squrared Error :{}".format(mean_squared_error(y_test ,lg.predict(x_test))))
#print("training Acuuracy:{}".format(r2_score(x_train ,y_train)))
print("testing Accuracy_score:{}".format(r2_score(y_test ,lg.predict(x_test))))
# Out:
# mean_squrared Error :2717211473.5002103
# testing Accuracy_score:0.58842082392942
# C:\Users\Karthick\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 189957928584.1963, tolerance: 679805682.3059437
#   positive)

# %%
for feature in categorical_value:
    data1 = data_train[feature].unique()
    print(data1)
# Out:
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
# ['Pave' 'Grvl']
# ['None' 'Grvl' 'Pave']
# ['Reg' 'IR1' 'IR2' 'IR3']
# ['Lvl' 'Bnk' 'Low' 'HLS']
# ['AllPub' 'NoSeWa']
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# ['Gtl' 'Mod' 'Sev']
# ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile']
# ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
# ...
